# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Challenge-1" data-toc-modified-id="Challenge-1-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Challenge 1</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Import-all-required-libraries." data-toc-modified-id="Import-all-required-libraries.-1.0.0.1"><span class="toc-item-num">1.0.0.1&nbsp;&nbsp;</span>Import all required libraries.</a></span></li><li><span><a href="#Import-data-set." data-toc-modified-id="Import-data-set.-1.0.0.2"><span class="toc-item-num">1.0.0.2&nbsp;&nbsp;</span>Import data set.</a></span></li><li><span><a href="#Print-first-10-rows-of-pokemon." data-toc-modified-id="Print-first-10-rows-of-pokemon.-1.0.0.3"><span class="toc-item-num">1.0.0.3&nbsp;&nbsp;</span>Print first 10 rows of <code>pokemon</code>.</a></span></li><li><span><a href="#Obtain-the-distinct-values-across-Type-1-and-Type-2." data-toc-modified-id="Obtain-the-distinct-values-across-Type-1-and-Type-2.-1.0.0.4"><span class="toc-item-num">1.0.0.4&nbsp;&nbsp;</span>Obtain the distinct values across <code>Type 1</code> and <code>Type 2</code>.</a></span></li><li><span><a href="#Cleanup-Name-that-contain-&quot;Mega&quot;." data-toc-modified-id="Cleanup-Name-that-contain-&quot;Mega&quot;.-1.0.0.5"><span class="toc-item-num">1.0.0.5&nbsp;&nbsp;</span>Cleanup <code>Name</code> that contain "Mega".</a></span></li><li><span><a href="#Create-a-new-column-called-A/D-Ratio-whose-value-equals-to-Attack-devided-by-Defense." data-toc-modified-id="Create-a-new-column-called-A/D-Ratio-whose-value-equals-to-Attack-devided-by-Defense.-1.0.0.6"><span class="toc-item-num">1.0.0.6&nbsp;&nbsp;</span>Create a new column called <code>A/D Ratio</code> whose value equals to <code>Attack</code> devided by <code>Defense</code>.</a></span></li><li><span><a href="#Identify-the-pokemon-with-the-highest-A/D-Ratio." data-toc-modified-id="Identify-the-pokemon-with-the-highest-A/D-Ratio.-1.0.0.7"><span class="toc-item-num">1.0.0.7&nbsp;&nbsp;</span>Identify the pokemon with the highest <code>A/D Ratio</code>.</a></span></li><li><span><a href="#Identify-the-pokemon-with-the-lowest-A/D-Ratio." data-toc-modified-id="Identify-the-pokemon-with-the-lowest-A/D-Ratio.-1.0.0.8"><span class="toc-item-num">1.0.0.8&nbsp;&nbsp;</span>Identify the pokemon with the lowest A/D Ratio.</a></span></li><li><span><a href="#Create-a-new-column-called-Combo-Type-whose-value-combines-Type-1-and-Type-2." data-toc-modified-id="Create-a-new-column-called-Combo-Type-whose-value-combines-Type-1-and-Type-2.-1.0.0.9"><span class="toc-item-num">1.0.0.9&nbsp;&nbsp;</span>Create a new column called <code>Combo Type</code> whose value combines <code>Type 1</code> and <code>Type 2</code>.</a></span></li><li><span><a href="#Identify-the-pokemon-whose-A/D-Ratio-are-among-the-top-5." data-toc-modified-id="Identify-the-pokemon-whose-A/D-Ratio-are-among-the-top-5.-1.0.0.10"><span class="toc-item-num">1.0.0.10&nbsp;&nbsp;</span>Identify the pokemon whose <code>A/D Ratio</code> are among the top 5.</a></span></li><li><span><a href="#For-the-5-pokemon-printed-above,-aggregate-Combo-Type-and-use-a-list-to-store-the-unique-values." data-toc-modified-id="For-the-5-pokemon-printed-above,-aggregate-Combo-Type-and-use-a-list-to-store-the-unique-values.-1.0.0.11"><span class="toc-item-num">1.0.0.11&nbsp;&nbsp;</span>For the 5 pokemon printed above, aggregate <code>Combo Type</code> and use a list to store the unique values.</a></span></li><li><span><a href="#For-each-of-the-Combo-Type-values-obtained-from-the-previous-question,-calculate-the-mean-scores-of-all-numeric-fields-across-all-pokemon." data-toc-modified-id="For-each-of-the-Combo-Type-values-obtained-from-the-previous-question,-calculate-the-mean-scores-of-all-numeric-fields-across-all-pokemon.-1.0.0.12"><span class="toc-item-num">1.0.0.12&nbsp;&nbsp;</span>For each of the <code>Combo Type</code> values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
# import libraries
import pandas as pd

# %% [markdown]
# #### Import data set.
#
# Import data set `Pokemon` from Ironhack's database. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set from Ironhack's database
df=pd.read_csv(r'D:\Repositories\data-ft-par-labs\Labs\module_1\15. Dataframe-Calculations\Data/Pokemon.csv')

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
# your code here


df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# your code here
import numpy as np
array= np.array(df['Type 1'] +' '+ df['Type 2'])

array
# Out:
# array(['Grass Poison', 'Grass Poison', 'Grass Poison', 'Grass Poison',
#        nan, nan, 'Fire Flying', 'Fire Dragon', 'Fire Flying', nan, nan,
#        nan, nan, nan, nan, 'Bug Flying', 'Bug Poison', 'Bug Poison',
#        'Bug Poison', 'Bug Poison', 'Normal Flying', 'Normal Flying',
#        'Normal Flying', 'Normal Flying', nan, nan, 'Normal Flying',
#        'Normal Flying', nan, nan, nan, nan, nan, nan, nan, nan,
#        'Poison Ground', nan, nan, 'Poison Ground', nan, nan, nan, nan,
#        'Normal Fairy', 'Normal Fairy', 'Poison Flying', 'Poison Flying',
#        'Grass Poison', 'Grass Poison', 'Grass Poison', 'Bug Grass',
#        'Bug Grass', 'Bug Poison', 'Bug Poison', nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, 'Water Fighting', nan, nan, nan,
#        nan, nan, nan, nan, 'Grass Poison', 'Grass Poison', 'Grass Poison',
#        'Water Poison', 'Water Poison', 'Rock Ground', 'Rock Ground',
#        'Rock Ground', nan, nan, 'Water Psychic', 'Water Psychic',
#        'Water Psychic', 'Electric Steel', 'Electric Steel',
#        'Normal Flying', 'Normal Flying', 'Normal Flying', nan,
#        'Water Ice', nan, nan, nan, 'Water Ice', 'Ghost Poison',
#        'Ghost Poison', 'Ghost Poison', 'Ghost Poison', 'Rock Ground', nan,
#        nan, nan, nan, nan, nan, 'Grass Psychic', 'Grass Psychic', nan,
#        nan, nan, nan, nan, nan, nan, 'Ground Rock', 'Ground Rock', nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, 'Water Psychic',
#        'Psychic Fairy', 'Bug Flying', 'Ice Psychic', nan, nan, nan,
#        'Bug Flying', nan, nan, 'Water Flying', 'Water Dark', 'Water Ice',
#        nan, nan, nan, nan, nan, nan, 'Rock Water', 'Rock Water',
#        'Rock Water', 'Rock Water', 'Rock Flying', 'Rock Flying', nan,
#        'Ice Flying', 'Electric Flying', 'Fire Flying', nan, nan,
#        'Dragon Flying', nan, 'Psychic Fighting', nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, 'Normal Flying',
#        'Normal Flying', 'Bug Flying', 'Bug Flying', 'Bug Poison',
#        'Bug Poison', 'Poison Flying', 'Water Electric', 'Water Electric',
#        nan, nan, 'Normal Fairy', nan, 'Fairy Flying', 'Psychic Flying',
#        'Psychic Flying', nan, nan, nan, 'Electric Dragon', nan,
#        'Water Fairy', 'Water Fairy', nan, nan, 'Grass Flying',
#        'Grass Flying', 'Grass Flying', nan, nan, nan, 'Bug Flying',
#        'Water Ground', 'Water Ground', nan, nan, 'Dark Flying',
#        'Water Psychic', nan, nan, nan, 'Normal Psychic', nan, 'Bug Steel',
#        nan, 'Ground Flying', 'Steel Ground', 'Steel Ground', nan, nan,
#        'Water Poison', 'Bug Steel', 'Bug Steel', 'Bug Rock',
#        'Bug Fighting', 'Bug Fighting', 'Dark Ice', nan, nan, nan,
#        'Fire Rock', 'Ice Ground', 'Ice Ground', 'Water Rock', nan, nan,
#        'Ice Flying', 'Water Flying', 'Steel Flying', 'Dark Fire',
#        'Dark Fire', 'Dark Fire', 'Water Dragon', nan, nan, nan, nan, nan,
#        nan, nan, 'Ice Psychic', nan, nan, nan, nan, nan, nan, nan,
#        'Rock Ground', 'Rock Ground', 'Rock Dark', 'Rock Dark',
#        'Psychic Flying', 'Fire Flying', 'Psychic Grass', nan, nan, nan,
#        'Grass Dragon', nan, 'Fire Fighting', 'Fire Fighting',
#        'Fire Fighting', nan, 'Water Ground', 'Water Ground',
#        'Water Ground', nan, nan, nan, nan, nan, nan, 'Bug Flying', nan,
#        'Bug Poison', 'Water Grass', 'Water Grass', 'Water Grass', nan,
#        'Grass Dark', 'Grass Dark', 'Normal Flying', 'Normal Flying',
#        'Water Flying', 'Water Flying', 'Psychic Fairy', 'Psychic Fairy',
#        'Psychic Fairy', 'Psychic Fairy', 'Bug Water', 'Bug Flying', nan,
#        'Grass Fighting', nan, nan, nan, 'Bug Ground', 'Bug Flying',
#        'Bug Ghost', nan, nan, nan, nan, nan, 'Normal Fairy', nan, nan,
#        nan, 'Dark Ghost', 'Dark Ghost', 'Steel Fairy', 'Steel Fairy',
#        'Steel Rock', 'Steel Rock', 'Steel Rock', nan, 'Fighting Psychic',
#        'Fighting Psychic', 'Fighting Psychic', nan, nan, nan, nan, nan,
#        nan, nan, 'Grass Poison', nan, nan, 'Water Dark', 'Water Dark',
#        'Water Dark', nan, nan, 'Fire Ground', 'Fire Ground',
#        'Fire Ground', nan, nan, nan, nan, nan, 'Ground Dragon',
#        'Ground Dragon', nan, 'Grass Dark', 'Normal Flying',
#        'Dragon Flying', 'Dragon Fairy', nan, nan, 'Rock Psychic',
#        'Rock Psychic', 'Water Ground', 'Water Ground', nan, 'Water Dark',
#        'Ground Psychic', 'Ground Psychic', 'Rock Grass', 'Rock Grass',
#        'Rock Bug', 'Rock Bug', nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, 'Grass Flying', nan, nan, nan, nan, nan, nan, nan,
#        'Ice Water', 'Ice Water', 'Ice Water', nan, nan, nan, 'Water Rock',
#        nan, nan, nan, 'Dragon Flying', 'Dragon Flying', 'Steel Psychic',
#        'Steel Psychic', 'Steel Psychic', 'Steel Psychic', nan, nan, nan,
#        'Dragon Psychic', 'Dragon Psychic', 'Dragon Psychic',
#        'Dragon Psychic', nan, nan, nan, 'Ground Fire', 'Dragon Flying',
#        'Dragon Flying', 'Steel Psychic', nan, nan, nan, nan, nan, nan,
#        'Grass Ground', nan, 'Fire Fighting', 'Fire Fighting', nan, nan,
#        'Water Steel', 'Normal Flying', 'Normal Flying', 'Normal Flying',
#        nan, 'Normal Water', nan, nan, nan, nan, nan, 'Grass Poison',
#        'Grass Poison', nan, nan, 'Rock Steel', 'Rock Steel', nan,
#        'Bug Grass', 'Bug Ground', 'Bug Steel', 'Bug Flying', 'Bug Flying',
#        'Bug Flying', nan, nan, nan, nan, nan, nan, 'Water Ground', nan,
#        'Ghost Flying', 'Ghost Flying', nan, nan, 'Normal Fighting', nan,
#        'Dark Flying', nan, nan, nan, 'Poison Dark', 'Poison Dark',
#        'Steel Psychic', 'Steel Psychic', nan, 'Psychic Fairy', nan,
#        'Normal Flying', 'Ghost Dark', 'Dragon Ground', 'Dragon Ground',
#        'Dragon Ground', 'Dragon Ground', nan, nan, 'Fighting Steel',
#        'Fighting Steel', nan, nan, 'Poison Bug', 'Poison Dark',
#        'Poison Fighting', 'Poison Fighting', nan, nan, nan,
#        'Water Flying', 'Grass Ice', 'Grass Ice', 'Grass Ice', 'Dark Ice',
#        'Electric Steel', nan, 'Ground Rock', nan, nan, nan,
#        'Fairy Flying', 'Bug Flying', nan, nan, 'Ground Flying',
#        'Ice Ground', nan, 'Psychic Fighting', 'Psychic Fighting',
#        'Rock Steel', nan, 'Ice Ghost', 'Electric Ghost', 'Electric Fire',
#        'Electric Water', 'Electric Ice', 'Electric Flying',
#        'Electric Grass', nan, nan, nan, 'Steel Dragon', 'Water Dragon',
#        'Fire Steel', nan, 'Ghost Dragon', 'Ghost Dragon', nan, nan, nan,
#        nan, nan, 'Grass Flying', nan, 'Psychic Fire', nan, nan, nan, nan,
#        'Fire Fighting', 'Fire Fighting', nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        'Normal Flying', 'Normal Flying', 'Normal Flying', nan, nan, nan,
#        nan, nan, 'Psychic Flying', 'Psychic Flying', nan, 'Ground Steel',
#        nan, 'Normal Fairy', nan, nan, nan, nan, 'Water Ground',
#        'Water Ground', nan, nan, 'Bug Grass', 'Bug Grass', 'Bug Grass',
#        'Bug Poison', 'Bug Poison', 'Bug Poison', 'Grass Fairy',
#        'Grass Fairy', nan, nan, nan, 'Ground Dark', 'Ground Dark',
#        'Ground Dark', nan, nan, 'Fire Psychic', nan, 'Bug Rock',
#        'Bug Rock', 'Dark Fighting', 'Dark Fighting', 'Psychic Flying',
#        nan, nan, 'Water Rock', 'Water Rock', 'Rock Flying', 'Rock Flying',
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        'Water Flying', 'Water Flying', nan, nan, nan, 'Normal Grass',
#        'Normal Grass', 'Electric Flying', nan, 'Bug Steel',
#        'Grass Poison', 'Grass Poison', 'Water Ghost', 'Water Ghost', nan,
#        'Bug Electric', 'Bug Electric', 'Grass Steel', 'Grass Steel', nan,
#        nan, nan, nan, nan, nan, nan, nan, 'Ghost Fire', 'Ghost Fire',
#        'Ghost Fire', nan, nan, nan, nan, nan, nan, nan, nan,
#        'Ground Electric', nan, nan, nan, 'Ground Ghost', 'Ground Ghost',
#        'Dark Steel', 'Dark Steel', nan, 'Normal Flying', 'Normal Flying',
#        'Dark Flying', 'Dark Flying', nan, 'Bug Steel', 'Dark Dragon',
#        'Dark Dragon', 'Dark Dragon', 'Bug Fire', 'Bug Fire',
#        'Steel Fighting', 'Rock Fighting', 'Grass Fighting', nan, nan,
#        'Electric Flying', 'Electric Flying', 'Dragon Fire',
#        'Dragon Electric', 'Ground Flying', 'Ground Flying', 'Dragon Ice',
#        'Dragon Ice', 'Dragon Ice', 'Water Fighting', 'Water Fighting',
#        'Normal Psychic', 'Normal Fighting', 'Bug Steel', nan, nan,
#        'Grass Fighting', nan, nan, 'Fire Psychic', nan, nan, 'Water Dark',
#        nan, 'Normal Ground', 'Normal Flying', 'Fire Flying',
#        'Fire Flying', nan, nan, 'Bug Flying', 'Fire Normal',
#        'Fire Normal', nan, nan, nan, nan, nan, nan, 'Fighting Dark', nan,
#        nan, nan, nan, 'Steel Ghost', 'Steel Ghost', 'Steel Ghost',
#        'Steel Ghost', nan, nan, nan, nan, 'Dark Psychic', 'Dark Psychic',
#        'Rock Water', 'Rock Water', 'Poison Water', 'Poison Dragon', nan,
#        nan, 'Electric Normal', 'Electric Normal', 'Rock Dragon',
#        'Rock Dragon', 'Rock Ice', 'Rock Ice', nan, 'Fighting Flying',
#        'Electric Fairy', 'Rock Fairy', nan, nan, nan, 'Steel Fairy',
#        'Ghost Grass', 'Ghost Grass', 'Ghost Grass', 'Ghost Grass',
#        'Ghost Grass', 'Ghost Grass', 'Ghost Grass', 'Ghost Grass',
#        'Ghost Grass', 'Ghost Grass', nan, nan, 'Flying Dragon',
#        'Flying Dragon', nan, 'Dark Flying', 'Dragon Ground', 'Rock Fairy',
#        'Rock Fairy', 'Psychic Ghost', 'Psychic Dark', 'Fire Water'],
#       dtype=object)

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
import re
### your code here

#first we need to detect the names which contains Mega 


#df.loc[df.Name.str.contains('Mega'), 'Name'] = 'Mega' +' '+ (df.Name.str.split().str.get(0))

#df.loc[df.Name.str.contains('Mega'), 'Name'] = 
# 'first_name']=df.Name.str.split(expand=True)[1]
#df.loc[df.Name.str.contains('Mega'), 'Mega'] = 'Mega'
#df.loc[df.Name.str.contains('Mega'), 'first_name'] = df.Name.str.split(expand=True)[1]
#df.loc[df.Name.str.contains('Mega'), 'Second_name'] = df.Name.str.split(expand=True)[2]
#df.loc[df.Name.str.contains('Mega'), 'Name'] = df.Name.str.cat(df.Mega +' '+ df.first_name +' '+ df.Second_name, na_rep='')
#df.loc[df.Name.str.contains('Mega'), 'right_name'] = df.right_name.str.cat(df.Mega +' '+ df.first_name +' '+ df.Second_name, na_rep='')
#df.loc[df.Name.str.contains('Mega'), 'right_name'] = df.name.str.cat(df.Mega +' '+ df.first_name +' '+ df.Second_name, na_rep='').split(expand=True)
#df.loc[df.Name.str.contains('Mega'), 'right_name'] =  df.Mega.str.cat(' '+ df.first_name +' '+ df.Second_name, na_rep='')

#df.loc[df.Name.str.contains('Mega')] = df.Name.str.split(expand=True)
#df.loc[df.Name.str.contains('Mega')] = df.Name.str.split(expand=True)
#df.loc[df.Name.str.contains('Mega'), 'Second'] = df.Name.str.split().str.get(2)
#df.loc[df.Name.str.contains('Mega'), 'Name'] =  df.first_name.str.cat('Mega'+' '+ df.Second, na_rep='')
#df.loc[df.Name.str.contains('Mega'), 'Name'] = df.Name.str.split().str.get(1) 
#df.loc[df.Name.str.contains('Mega'), 'Name'] = df.Name.str.split(expand=True)

#df.loc[df.Name.str.contains('Mega'), 'Name'] = df.Name.str.replace('Mega','Name'[0])
#df.loc[df.Name.str.contains('Mega'), 'Name'] = df.Name.str.replace([df.Name.str.split().str.get(0)], 'Mega')
#df.loc[df.Name.str.contains('Mega'), 'Name'] = df.Name.str.replace([df.Name.str.split().str.get(0)], 'Mega')
#df.Name.str.replace([df.Name.str.split().str.get(0)], 'Mega')
#[df.Name.str.split().str.get(1)]
#df.loc[df.Name.str.contains('Mega'), 'Name'] = df.Name.str.replace([df.Name.str.split().str.get(0)], 'Mega')

df.loc[df.Name.str.contains(r'\b\w+Mega \b'), 'Name'] = df.Name.str.replace(r'\b\w+Mega \b', 'Mega ')
df.loc[df.Name.str.contains('Mega')]
# Out:
# <ipython-input-5-ccc6ad5a5622>:33: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.loc[df.Name.str.contains(r'\b\w+Mega \b'), 'Name'] = df.Name.str.replace(r'\b\w+Mega \b', 'Mega ')
#        #              Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 3      3     Mega Venusaur     Grass    Poison    625   80     100      123
# 7      6  Mega Charizard X      Fire    Dragon    634   78     130      111
# 8      6  Mega Charizard Y      Fire    Flying    634   78     104       78
# 12     9    Mega Blastoise     Water       NaN    630   79     103      120
# 19    15     Mega Beedrill       Bug    Poison    495   65     150       40
# 23    18      Mega Pidgeot    Normal    Flying    579   83      80       80
# 71    65     Mega Alakazam   Psychic       NaN    590   55      50       65
# 87    80      Mega Slowbro     Water   Psychic    590   95      75      180
# 102   94       Mega Gengar     Ghost    Poison    600   60      65       80
# 124  115   Mega Kangaskhan    Normal       NaN    590  105     125      100
# 137  127       Mega Pinsir       Bug    Flying    600   65     155      120
# 141  130     Mega Gyarados     Water      Dark    640   95     155      109
# 154  142   Mega Aerodactyl      Rock    Flying    615   80     135       85
# 163  150     Mega Mewtwo X   Psychic  Fighting    780  106     190      100
# 164  150     Mega Mewtwo Y   Psychic       NaN    780  106     150       70
# 168  154          Meganium     Grass       NaN    525   80      82      100
# 196  181     Mega Ampharos  Electric    Dragon    610   90      95      105
# 224  208      Mega Steelix     Steel    Ground    610   75     125      230
# 229  212       Mega Scizor       Bug     Steel    600   70     150      140
# 232  214    Mega Heracross       Bug  Fighting    600   80     185      115
# 248  229     Mega Houndoom      Dark      Fire    600   75      90       90
# 268  248    Mega Tyranitar      Rock      Dark    700  100     164      150
# 275  254     Mega Sceptile     Grass    Dragon    630   70     110       75
# 279  257     Mega Blaziken      Fire  Fighting    630   80     160       80
# 283  260     Mega Swampert     Water    Ground    635  100     150      110
# 306  282    Mega Gardevoir   Psychic     Fairy    618   68      85       65
# 327  302      Mega Sableye      Dark     Ghost    480   50      85      125
# 329  303       Mega Mawile     Steel     Fairy    480   50     105      125
# 333  306       Mega Aggron     Steel       NaN    630   70     140      230
# 336  308     Mega Medicham  Fighting   Psychic    510   60     100       85
# 339  310    Mega Manectric  Electric       NaN    575   70      75       80
# 349  319     Mega Sharpedo     Water      Dark    560   70     140       70
# 354  323     Mega Camerupt      Fire    Ground    560   70     120      100
# 366  334      Mega Altaria    Dragon     Fairy    590   75     110      110
# 387  354      Mega Banette     Ghost       NaN    555   64     165       75
# 393  359        Mega Absol      Dark       NaN    565   65     150       60
# 397  362       Mega Glalie       Ice       NaN    580   80     120       80
# 409  373    Mega Salamence    Dragon    Flying    700   95     145      130
# 413  376    Mega Metagross     Steel   Psychic    700   80     145      150
# 418  380       Mega Latias    Dragon   Psychic    700   80     100      120
# 420  381       Mega Latios    Dragon   Psychic    700   80     130      100
# 426  384     Mega Rayquaza    Dragon    Flying    780  105     180      100
# 476  428      Mega Lopunny    Normal  Fighting    580   65     136       94
# 494  445     Mega Garchomp    Dragon    Ground    700  108     170      115
# 498  448      Mega Lucario  Fighting     Steel    625   70     145       88
# 511  460    Mega Abomasnow     Grass       Ice    594   90     132      105
# 527  475      Mega Gallade   Psychic  Fighting    618   68     165       95
# 591  531       Mega Audino    Normal     Fairy    545  103      60      126
# 796  719      Mega Diancie      Rock     Fairy    700   50     160      110
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 3        122      120     80           1      False
# 7        130       85    100           1      False
# 8        159      115    100           1      False
# 12       135      115     78           1      False
# 19        15       80    145           1      False
# 23       135       80    121           1      False
# 71       175       95    150           1      False
# 87       130       80     30           1      False
# 102      170       95    130           1      False
# 124       60      100    100           1      False
# 137       65       90    105           1      False
# 141       70      130     81           1      False
# 154       70       95    150           1      False
# 163      154      100    130           1       True
# 164      194      120    140           1       True
# 168       83      100     80           2      False
# 196      165      110     45           2      False
# 224       55       95     30           2      False
# 229       65      100     75           2      False
# 232       40      105     75           2      False
# 248      140       90    115           2      False
# 268       95      120     71           2      False
# 275      145       85    145           3      False
# 279      130       80    100           3      False
# 283       95      110     70           3      False
# 306      165      135    100           3      False
# 327       85      115     20           3      False
# 329       55       95     50           3      False
# 333       60       80     50           3      False
# 336       80       85    100           3      False
# 339      135       80    135           3      False
# 349      110       65    105           3      False
# 354      145      105     20           3      False
# 366      110      105     80           3      False
# 387       93       83     75           3      False
# 393      115       60    115           3      False
# 397      120       80    100           3      False
# 409      120       90    120           3      False
# 413      105      110    110           3      False
# 418      140      150    110           3       True
# 420      160      120    110           3       True
# 426      180      100    115           3       True
# 476       54       96    135           4      False
# 494      120       95     92           4      False
# 498      140       70    112           4      False
# 511      132      105     30           4      False
# 527       65      115    110           4      False
# 591       80      126     50           5      False
# 796      160      110    110           6       True

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# your code here

df['A/D Ratio'] = (df['Attack']/df['Defense'])
df.head(20)
# Out:
#      #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0    1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1    2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2    3          Venusaur  Grass  Poison    525  80      82       83      100
# 3    3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4    4        Charmander   Fire     NaN    309  39      52       43       60
# 5    5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6    6         Charizard   Fire  Flying    534  78      84       78      109
# 7    6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8    6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9    7          Squirtle  Water     NaN    314  44      48       65       50
# 10   8         Wartortle  Water     NaN    405  59      63       80       65
# 11   9         Blastoise  Water     NaN    530  79      83      100       85
# 12   9    Mega Blastoise  Water     NaN    630  79     103      120      135
# 13  10          Caterpie    Bug     NaN    195  45      30       35       20
# 14  11           Metapod    Bug     NaN    205  50      20       55       25
# 15  12        Butterfree    Bug  Flying    395  60      45       50       90
# 16  13            Weedle    Bug  Poison    195  40      35       30       20
# 17  14            Kakuna    Bug  Poison    205  45      25       50       25
# 18  15          Beedrill    Bug  Poison    395  65      90       40       45
# 19  15     Mega Beedrill    Bug  Poison    495  65     150       40       15
#
#     Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 0        65     45           1      False   1.000000
# 1        80     60           1      False   0.984127
# 2       100     80           1      False   0.987952
# 3       120     80           1      False   0.813008
# 4        50     65           1      False   1.209302
# 5        65     80           1      False   1.103448
# 6        85    100           1      False   1.076923
# 7        85    100           1      False   1.171171
# 8       115    100           1      False   1.333333
# 9        64     43           1      False   0.738462
# 10       80     58           1      False   0.787500
# 11      105     78           1      False   0.830000
# 12      115     78           1      False   0.858333
# 13       20     45           1      False   0.857143
# 14       25     30           1      False   0.363636
# 15       80     70           1      False   0.900000
# 16       20     50           1      False   1.166667
# 17       25     35           1      False   0.500000
# 18       80     75           1      False   2.250000
# 19       80    145           1      False   3.750000

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
# your code here

df['A/D Ratio'].max()
# Out:
# 9.0

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
# your code here
df['A/D Ratio'].min()
# Out:
# 0.043478260869565216

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
# your code here

df['Combo Type'] = df['Type 1'].str.cat('-'+ df['Type 2'], na_rep='')

df.head(30)
# Out:
#      #              Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0    1         Bulbasaur   Grass  Poison    318  45      49       49       65
# 1    2           Ivysaur   Grass  Poison    405  60      62       63       80
# 2    3          Venusaur   Grass  Poison    525  80      82       83      100
# 3    3     Mega Venusaur   Grass  Poison    625  80     100      123      122
# 4    4        Charmander    Fire     NaN    309  39      52       43       60
# 5    5        Charmeleon    Fire     NaN    405  58      64       58       80
# 6    6         Charizard    Fire  Flying    534  78      84       78      109
# 7    6  Mega Charizard X    Fire  Dragon    634  78     130      111      130
# 8    6  Mega Charizard Y    Fire  Flying    634  78     104       78      159
# 9    7          Squirtle   Water     NaN    314  44      48       65       50
# 10   8         Wartortle   Water     NaN    405  59      63       80       65
# 11   9         Blastoise   Water     NaN    530  79      83      100       85
# 12   9    Mega Blastoise   Water     NaN    630  79     103      120      135
# 13  10          Caterpie     Bug     NaN    195  45      30       35       20
# 14  11           Metapod     Bug     NaN    205  50      20       55       25
# 15  12        Butterfree     Bug  Flying    395  60      45       50       90
# 16  13            Weedle     Bug  Poison    195  40      35       30       20
# 17  14            Kakuna     Bug  Poison    205  45      25       50       25
# 18  15          Beedrill     Bug  Poison    395  65      90       40       45
# 19  15     Mega Beedrill     Bug  Poison    495  65     150       40       15
# 20  16            Pidgey  Normal  Flying    251  40      45       40       35
# 21  17         Pidgeotto  Normal  Flying    349  63      60       55       50
# 22  18           Pidgeot  Normal  Flying    479  83      80       75       70
# 23  18      Mega Pidgeot  Normal  Flying    579  83      80       80      135
# 24  19           Rattata  Normal     NaN    253  30      56       35       25
# 25  20          Raticate  Normal     NaN    413  55      81       60       50
# 26  21           Spearow  Normal  Flying    262  40      60       30       31
# 27  22            Fearow  Normal  Flying    442  65      90       65       61
# 28  23             Ekans  Poison     NaN    288  35      60       44       40
# 29  24             Arbok  Poison     NaN    438  60      85       69       65
#
#     Sp. Def  Speed  Generation  Legendary  A/D Ratio     Combo Type
# 0        65     45           1      False   1.000000   Grass-Poison
# 1        80     60           1      False   0.984127   Grass-Poison
# 2       100     80           1      False   0.987952   Grass-Poison
# 3       120     80           1      False   0.813008   Grass-Poison
# 4        50     65           1      False   1.209302           Fire
# 5        65     80           1      False   1.103448           Fire
# 6        85    100           1      False   1.076923    Fire-Flying
# 7        85    100           1      False   1.171171    Fire-Dragon
# 8       115    100           1      False   1.333333    Fire-Flying
# 9        64     43           1      False   0.738462          Water
# 10       80     58           1      False   0.787500          Water
# 11      105     78           1      False   0.830000          Water
# 12      115     78           1      False   0.858333          Water
# 13       20     45           1      False   0.857143            Bug
# 14       25     30           1      False   0.363636            Bug
# 15       80     70           1      False   0.900000     Bug-Flying
# 16       20     50           1      False   1.166667     Bug-Poison
# 17       25     35           1      False   0.500000     Bug-Poison
# 18       80     75           1      False   2.250000     Bug-Poison
# 19       80    145           1      False   3.750000     Bug-Poison
# 20       35     56           1      False   1.125000  Normal-Flying
# 21       50     71           1      False   1.090909  Normal-Flying
# 22       70    101           1      False   1.066667  Normal-Flying
# 23       80    121           1      False   1.000000  Normal-Flying
# 24       35     72           1      False   1.600000         Normal
# 25       70     97           1      False   1.350000         Normal
# 26       31     70           1      False   2.000000  Normal-Flying
# 27       61    100           1      False   1.384615  Normal-Flying
# 28       54     55           1      False   1.363636         Poison
# 29       79     80           1      False   1.231884         Poison

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
# your code here
#df.IMDb>8
df.loc[df['A/D Ratio']>=5]


df.sort_values(by='A/D Ratio', ascending=False).head(10)
# Out:
#        #                  Name    Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386    DeoxysAttack Forme   Psychic     NaN    600  50     180       20
# 347  318              Carvanha     Water    Dark    305  45      90       20
# 19    15         Mega Beedrill       Bug  Poison    495  65     150       40
# 453  408              Cranidos      Rock     NaN    350  67     125       40
# 348  319              Sharpedo     Water    Dark    460  70     120       40
# 428  386    DeoxysNormal Forme   Psychic     NaN    600  50     150       50
# 750  681  AegislashBlade Forme     Steel   Ghost    520  60     150       50
# 454  409             Rampardos      Rock     NaN    495  97     165       60
# 798  720    HoopaHoopa Unbound   Psychic    Dark    680  80     160       60
# 186  172                 Pichu  Electric     NaN    205  20      40       15
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio    Combo Type
# 429      180       20    150           3       True   9.000000       Psychic
# 347       65       20     65           3      False   4.500000    Water-Dark
# 19        15       80    145           1      False   3.750000    Bug-Poison
# 453       30       30     58           4      False   3.125000          Rock
# 348       95       40     95           3      False   3.000000    Water-Dark
# 428      150       50    150           3       True   3.000000       Psychic
# 750      150       50     60           6      False   3.000000   Steel-Ghost
# 454       65       50     58           4      False   2.750000          Rock
# 798      170      130     80           6       True   2.666667  Psychic-Dark
# 186       35       35     60           2      False   2.666667      Electric

# %%
ad_ratio = df.sort_values(by=['A/D Ratio', 'Legendary'], ascending=False).head(5)
ad_ratio
# Out:
#        #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic     NaN    600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15       Mega Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock     NaN    350  67     125       40
# 428  386  DeoxysNormal Forme  Psychic     NaN    600  50     150       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  Combo Type
# 429      180       20    150           3       True      9.000     Psychic
# 347       65       20     65           3      False      4.500  Water-Dark
# 19        15       80    145           1      False      3.750  Bug-Poison
# 453       30       30     58           4      False      3.125        Rock
# 428      150       50    150           3       True      3.000     Psychic

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
combo_type_lst = []
combo_type_lst = ad_ratio['Combo Type'].unique()
combo_type_lst
# Out:
# array(['Psychic', 'Water-Dark', 'Bug-Poison', 'Rock'], dtype=object)

# %%
#ad_ratio

# %%
#ad_ratio.apply(lambda x: sum(x)/len(x))

# %%
#ad_ratio.mean().mean()

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
# your code here
new_df= df.copy()

# %%
#newdf.set_index(index)

new_df.set_index('Combo Type', inplace=True)

# %%
new_df
# Out:
#                  #                 Name   Type 1  Type 2  Total  HP  Attack  \
# Combo Type
# Grass-Poison     1            Bulbasaur    Grass  Poison    318  45      49
# Grass-Poison     2              Ivysaur    Grass  Poison    405  60      62
# Grass-Poison     3             Venusaur    Grass  Poison    525  80      82
# Grass-Poison     3        Mega Venusaur    Grass  Poison    625  80     100
# Fire             4           Charmander     Fire     NaN    309  39      52
# ...            ...                  ...      ...     ...    ...  ..     ...
# Rock-Fairy     719              Diancie     Rock   Fairy    600  50     100
# Rock-Fairy     719         Mega Diancie     Rock   Fairy    700  50     160
# Psychic-Ghost  720  HoopaHoopa Confined  Psychic   Ghost    600  80     110
# Psychic-Dark   720   HoopaHoopa Unbound  Psychic    Dark    680  80     160
# Fire-Water     721            Volcanion     Fire   Water    600  80     110
#
#                Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# Combo Type
# Grass-Poison        49       65       65     45           1      False
# Grass-Poison        63       80       80     60           1      False
# Grass-Poison        83      100      100     80           1      False
# Grass-Poison       123      122      120     80           1      False
# Fire                43       60       50     65           1      False
# ...                ...      ...      ...    ...         ...        ...
# Rock-Fairy         150      100      150     50           6       True
# Rock-Fairy         110      160      110    110           6       True
# Psychic-Ghost       60      150      130     70           6       True
# Psychic-Dark        60      170      130     80           6       True
# Fire-Water         120      130       90     70           6       True
#
#                A/D Ratio
# Combo Type
# Grass-Poison    1.000000
# Grass-Poison    0.984127
# Grass-Poison    0.987952
# Grass-Poison    0.813008
# Fire            1.209302
# ...                  ...
# Rock-Fairy      0.666667
# Rock-Fairy      1.454545
# Psychic-Ghost   1.833333
# Psychic-Dark    2.666667
# Fire-Water      0.916667
#
# [800 rows x 14 columns]

# %%
mean_combo_type = new_df.groupby('Combo Type').mean()

# %%
mean_combo_type.sort_values(by=['A/D Ratio'], ascending=False).head(5)
# Out:
#                        #       Total          HP  Attack    Defense  \
# Combo Type
# Psychic-Dark  720.000000  680.000000   80.000000   160.0  60.000000
# Water-Dark    347.666667  493.833333   69.166667   120.0  65.166667
# Ground-Steel  530.000000  508.000000  110.000000   135.0  60.000000
# Bug-Ghost     292.000000  236.000000    1.000000    90.0  45.000000
# Rock-Flying   354.250000  524.500000   72.500000   123.0  65.000000
#
#                  Sp. Atk  Sp. Def       Speed  Generation  Legendary  \
# Combo Type
# Psychic-Dark  170.000000    130.0   80.000000    6.000000        1.0
# Water-Dark     88.833333     63.5   87.166667    3.166667        0.0
# Ground-Steel   50.000000     65.0   88.000000    5.000000        0.0
# Bug-Ghost      30.000000     30.0   40.000000    3.000000        0.0
# Rock-Flying    79.000000     70.0  115.000000    3.000000        0.0
#
#               A/D Ratio
# Combo Type
# Psychic-Dark   2.666667
# Water-Dark     2.291949
# Ground-Steel   2.250000
# Bug-Ghost      2.000000
# Rock-Flying    1.961589

# %%
df.sort_values(by='A/D Ratio', ascending=False)

# %%
((new_df.sort_values(by=['A/D Ratio', 'Legendary'], ascending=False).head(5))._get_numeric_data())

# %%
new_df_main = ((new_df.sort_values(by=['A/D Ratio', 'Legendary'], ascending=False).head(5))._get_numeric_data())

# %%
new_df_main

# %%
ad_ratio.apply(lambda x: sum(x)/len(x))

new_df_main.apply
